# %%
# iteration

L = [1,2,3]
for i in L:
    print(i)
# Out:
# 1
# 2
# 3

# %%
# iterator
L = [i for i in range(1,1000)]

import sys
print(sys.getsizeof(L))

X = range(1,1000)
print(sys.getsizeof(X))
# Out:
# 8856
# 48
